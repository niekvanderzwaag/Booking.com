# %%
#Imports
import numpy as np
import pandas as pd

#Settings for string legibility
pd.set_option('display.max_rows', 500)
pd.set_option("display.max_colwidth", -1)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#String manipulations
import re

#Visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12,6]
sns.set(style="darkgrid")

#Quality of life
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Booking_Jobs.csv')

# %%
print('Dataframe shape: ', df.shape)
df.head()
# Out:
# Dataframe shape:  (108, 2)
#                                                             Job Title  \
# 0  Data Engineer
# 1  Manager Data Science Insights - Content Agency
# 2  Senior Data Engineering Manager - Data & Machine Learning Platform
# 3  Senior Data Engineer - Data & Machine Learning Platform
# 4  Data Analyst Trip Foundations
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0  Data Engineer (Data Enablement) \n  About the company\nNot long ago, booking a trip to see the Eiffel Tower, stroll down New York’s iconic Madison Avenue or feel the sand between our toes on Copacabana Beach was complex and time consuming. Now it is simply a matter of a few taps on our smartphone.\n  In fact, that’s what we do at Booking.com. We make it easier for everyone to experience the world. And while that world might feel a little farther away right now, we’re busy preparing for when the world is ready to travel once more.\n  Across our offices worldwide, we continue to innovate. To solve for some of the most complex challenges in travel and technology, and to plan for the exciting developments that lie ahead. With strategic long-term investments into what we believe the future of travel can be, we are opening up new career opportunities that will have a strong impact on our mission.\n  We are united in the belief that our very human desire to explore the planet’s beauty and discover more about other people and cultures will endure. The world is waiting for us. Together, we will be ready.\n  Booking.com core values\nThink Customer First\nSucceed Together\nOwn It\nLearn Forever\nDo the Right Thing\n  Trips Business Unit (TBU) direction\n  At Booking.com we’re working to seamlessly connect every aspect of travel, and the TBU team is one of the cornerstones of our connected trip vision. We’re dedicated to helping travellers uncover the best transport options available to them around the world. To do this we need to offer the broadest selection of bookable transport options, and effortlessly match the right options to the right person at the right time. Our goal is to offer travellers the widest choice and the best customer experience no matter what transport option they choose.\n  About the teams.\nThe Trips Data & Science team at Booking.com look after data for ‘everything but the stay’ at Booking.com: Car Rental, Taxis, Public Transport, Attractions, and Flights.  This includes data platforms, management, warehousing, enrichment and machine learning functionality,  enabling teams across the organisation to understand and manage our business performance and improve the experience of our customers. You will be responsible for delivering products that advance data excellence and innovation within your product team, and across the business, helping us shape Booking.com’s Transport data journey.\n   Data Enablement Team\nWe are looking for an enthusiastic and proactive Data Engineer to join our Data Enablement Team to drive the rapid and robust delivery of data pipelines. You will be an advocate for our cloud migration, driving benefit through data modelling, supporting product teams, supporting key initiatives, transforming/enriching data, creating data pipelines, working with analysis to enable data driven insight and decision making across all elements of Trips.\n  B. Responsible \nAs a Data Engineer, you’ll join TBU to work alongside curious, energetic, and focused people. You are responsible for delivering our vision to create a fully integrated, scalable, high performance and compliant data platform and pipelines. You’ll help roadmap and deliver replacements for the current ad-hoc data solutions with strong foundations built on modern technologies and practices that will make it easy to produce large quantities of high quality data for consumption and analysis .\nImportant aspects and responsibilities of the job include:\nData engineering\nUsing standardized tooling and procedures work with business users to model and implement data pipelines which are performant, scalable, secure, well governed and monitorable.\nDiagnose and solve customer issues with data and data pipelines. Perform root cause analysis and where appropriate enhancements to prevent recurrence.\nEnd-to-end ownership of data quality in our core datasets and data pipelines. Engage with other teams to help them identify and resolve data quality issues\n ...
# 1  At Booking.com, data drives our decisions. Technology is at our core. And innovation is everywhere. But our company is more than datasets, lines of code or A/B tests. We’re the thrill of the first night in a new place. The excitement of the next morning. The friends you make. The journeys you take. The sights you see. And the food you sample. Through our products, partners and people, we can empower everyone to experience the world.\n\nWe are looking for a Manager Data Science Insights to join the Content Agency Analytics and Data Science team in the Marketing department.\nContent Agency is responsible for providing high quality scaled content solutions to the business. This role is positioned within the Content Agency Analytics team with main focus on generating insights, strategy and guide key decision making based on data.\n\nAs a Manager Data Science Insights you will be leading a team of Data Scientists and Data Analysts within a track of 15 data professionals. A successful candidate is able to build a strong team, support the team members with career development and connect well with the team members to provide guidance and remove roadblocks. You will be working closely with the product teams and business stakeholders within Content Agency and Marketing. You help them understand and steer their ongoing product development through proving or disproving causal relationships for the business, through advanced statistics, experimentation or alternative value measurement methodologies. You understand the dynamics of content in the two-side marketplace by leveraging extensive internal and external data sources and guide Content Agency organization in making the right decisions both for our partners and our customers by identifying and measuring incremental business impact.\n\nThe Manager DSI thinks strategically and identifies areas where data science can make a significant impact on the supporting department, builds team(s) by coaching and mentoring and translates data science vision and strategy. As\nmanagers, they are expected to be leaders in the area of data science and to have\nexperience as Data Scientist Insights.\n\n\nResponsibility\n\nLeadership:\n- Think strategically and identify areas where data science can make a significant impact on the supporting department (scope)\n- Build a strong team within their area, by coaching and developing\nIndividual Contributors and Team Leaders (if applicable).\n- Be able to prioritize work depending on business needs and keeping\nstakeholders aligned at all times\n- Translate data science insights vision and strategy into execution keeping in mind the needs and specificities of the team and the scope.\n\nCommercial Awareness:\n- Play an instrumental role in evolving and designing new applications of data science to business problems\n- Take ownership and understand goals and objectives of supporting business partners, translating them into DSI requirements/framework\n\nCraft:\n- Bring vision and strategy to improve efficiency in the way data science teams work\n- Drive implementation and deployment of complex projects within the scope\n- Work closely with the other managers to ensure teams are always working towards what’s most important for the customers and to help the department achieve its goals.\n- Work closely with team members to ensure data quality, provide technical and tactical support, remove roadblocks and provide active support\n- Drive actions from stakeholders leveraging expertise in data visualization and storytelling skills\n\nCommunication:\n- Is capable of articulating complex concepts in simple terms to senior stakeholders\n- Is the advocate of data science with their main stakeholder(s)\n- Work closely with other internal entities to ensure their teams are always working towards what’s most important for customers and to achieve high business impact\n- Ensure clear and effective communication to their stakeholders: proactively keeps all stakeholders inform ...
# 2  It wasn’t so long  ago that booking a trip to see the Eiffel Tower, stroll down New York’s iconic Madison Avenue or feel the sand between our toes on Copacabana Beach was simply a matter of a few taps on our smartphone.\nIn fact, that’s what we do at Booking.com. We make it easier for everyone to experience the world. And while that world might feel a little farther away right now, we’re busy preparing for when the world is ready to travel once more.\nAcross our offices worldwide, we continue to innovate. To solve for some of the most complex challenges in travel and technology, and to plan for the exciting developments that lie ahead. With strategic long-term investments into what we believe the future of travel can be, we are opening up new career opportunities that will have a strong impact on our mission.\nWe are united in the belief that our very human desire to explore the planet’s beauty and discover more about other people and cultures will endure. The world is waiting for us. Together, we will be ready.\nAs a Senior Data Engineering Manager you are a senior thought leader and people manager for multiple teams of data managers and data engineers entrusted with one of our most business-critical assets - our data. Combining your technical subject matter expertise and extensive people leadership skills, you drive how your teams develop and implement processes and technology solutions for production and consumption of data across a broad area of the company, at scale, offline, and in real-time, following data governance requirements and development standards. You are a mentor to the leaders on your team on people management and technical elements of the data management & engineering craft, and on how to best apply them in our evolving business objectives and technology landscape. With your teams working on a large number of product development or strategic insights efforts simultaneously, you maintain a horizontal view across their work and build the necessary frameworks and processes to ensure consistent standards are applied and leverage is created through extensibility and reuse. \nResponsible\nDrive the creation of logical and physical data models that can be operationalised within the company’s workflows and infrastructure to ensure data solutions meet business requirements\nDrive mapping of data flows between systems and workflows within your teams' scope and identify opportunities for driving increased efficiency and ensuring proper controls \nManage the portfolio of data assets in your teams' scope, ensuring proper segmentation into sustainable and business-enabling domains by applying domain-driven design and enterprise architecture best practices\nManage development of scalable tooling for data flow automation and controls to manage the entire data life-cycle\nDevelop processes for implementing efficient data ingestion solutions, batch processing, and event-based streams to enable real-time actions and rapid business decisions\nDrive alignment with other leaders on relevant SLIs and SLOs for your teams to ensure full ownership of data solutions end-to-end, and monitor their performance across your portfolio of data assets to drive its overall health\nEnsure proper definition of quality requirements for data domains and data assets, based on standards for all data quality dimensions, to ensure design of high-quality data solutions\nDevelop approaches for monitoring, failure detection, and data availability across your teams to ensure data timeliness and completeness \nWork with other leaders in designing data definitions against specific business uses with adherence to all data protection standards to ensure data precision and integrity\nOwn your teams' delivery of high quality data end-to-end\nChoose the right technology or coding methodology by understanding customer needs\nMaintain a highly cross-disciplinary perspective, solving issues by applying approaches and methods from across a variety of data discipl ...
# 3  Booking.com is proud to be an equal opportunity workplace and is an affirmative action employer. All qualified applicants will receive consideration for employment without regard to race, colour, religion, gender, gender identity or expression, sexual orientation, national origin, genetics, disability, age, or veteran status. We strive to move well beyond traditional equal opportunity and work to create an environment that allows everyone to thrive\nThe Senior Data Engineer is a technical leader who drives data engineering strategies and delivery across a team. You will lead solution envisaging, technical designs, and hands-on implementation. You need to influence, differentiate, and guide the business and technology strategies, as they relate to data, through constant cross-functional interaction. You ask the right questions to the right people in order to align data strategy with commercial strategy, demonstrating technical expertise and business knowledge. \n  Responsibility\n- Support the data requirements of new and existing solutions by developing scalable and extensible physical data models that can be operationalised within the company’s workflows and infrastructure\n- Drive efficiency and resilience by mapping data flows between systems and workflows across the company\n- Ensure standardisation by following design patterns in line with global and local data governance requirements\n- Support real- time internal and customer- facing actions by developing real- time event- based streaming data pipelines\n- Enable rapid data- driven business decisions by developing efficient and scalable data ingestion solutions \n- Drive high- value data by connecting different disparate datasets from different systems into a well- managed unified solution\n- Own end- to- end data and data applications by defining, monitoring and adjusting relevant SLIs and SLOs\n- Handle, mitigate and learn from incidents in a manner that improves the overall system health\n- Ensure accuracy by developing criteria, automation, and processes for data production, transport, transform, and storage\n- Ensure compliance with data- related requirements by building solutions in line with all applicable standards and regulations\n- Ensure ongoing resilience of data processes by monitoring system performance and acting proactively identifying bottlenecks, potential risks, and failure point that might degrade overall quality\n- Build software applications by using the relevant development languages and applying in- depth knowledge of the systems, services and tools used by the specific business area\n- Write readable and reusable code by applying standard patterns and using standard libraries\n- Continuously evolve your craft by keeping up to date with the latest developments in data engineering and related technologies, introducing them to the community and promoting their application in areas where they can generate impact.\n- Actively contribute to Data Engineering at Booking.com through training, exploration of new technologies, interviewing, onboarding and mentoring colleagues.\n- Push for improvements, scaling and extending data engineering tooling and infrastructure, collaborating with central teams.\n\nYou are a role model of the Booking.com values:\nThrive on change and get things done\nDemand a high standard of excellence in their craft\nEmbrace the opportunity to improve\nUnderstand success starts with accountability and ownership\nCare more about being successful and reaching goals together than individually\nCurious, experiments and continuously learns\nHumble, open, friendly and remembers that diversity gives us strength\n  Level of Education\nBachelors degree in Computer Science or related field\nMasters degree in Computer Science or related field\nYears of relevant Job Knowledge\n6+ years of experience in a data engineering or related field using a server side programming languages, preferably Scala, Java, Python, or Perl\n4+ years of experien ...
# 4  It wasn’t so long ago that booking a trip to see the Eiffel Tower, stroll down New York’s iconic Madison Avenue or feel the sand between our toes on Copacabana Beach was simply a matter of a few taps on our smartphone.\nIn fact, that’s what we do at Booking.com. We make it easier for everyone to experience the world. And while that world might feel a little farther away right now, we’re busy preparing for when the world is ready to travel once more.\nAcross our offices worldwide, we continue to innovate. To solve for some of the most complex challenges in travel and technology, and to plan for the exciting developments that lie ahead. With strategic long-term investments into what we believe the future of travel can be, we are opening up new career opportunities that will have a strong impact on our mission.\nWe are united in the belief that our very human desire to explore the planet’s beauty and discover more about other people and cultures will endure. The world is waiting for us. Together, we will be ready.\nBooking.com core values\nThink customer first\nSucceed together\nOwn It\nLearn Forever\nDo the Right Thing\nAbout The Role\nAt Booking.com, data drives our decisions. Technology is at our core. And innovation is everywhere. But our company is more than datasets, lines of code or A/B tests. We’re the thrill of the first night in a new place. The excitement of the next morning. The friends you make. The journeys you take. The sights you see. And the food you sample. Through our products, partners and people, we can empower everyone to experience the world.\nThe Trips department mission is to deliver travellers the most seamless booking experience and best value on everything they need for their trip. From a customer perspective it means providing a connected multi-product offering from accommodation to flights to cars and more. We believe the intelligent combination of everything you need for your trip will be more valuable for customers and will help to define the future of travel and Booking.com.\nWithin the Trips family, we’re looking for a data analyst to help our trip foundations group that operates at the heart of our multi-vertical strategy. As part of trip foundations we aim to help our customers discover more for their next trip. You’ll connect and work with teams all across the company to help develop and deliver insights into customer behaviour, promotional performance, as well as estimating new opportunities for the business.\nYou’ll be working with Product Managers, Engineers, Analysts, data scientists and more within the trip foundations area, as well as other key parts of the business to help us understand, interpret and solve some of the most interesting challenges at Booking.com.\nJoin us and help us solve the critical business problems and questions, to enable us to help users plan and book more for their trip in the most seamless way possible.\nKey Responsibilities\nWorking with Trips Product Managers to generate and iterate hypotheses for cross-sell experiments which provide learnings and/or commercial benefit\nBuilding reporting suites to support our connected trip proposition\nWorking with engineers to log new data points to enhance insight into product performance \nBuilding data pipelines and designing schema \nAutomating processes to efficiently manage reporting requirements, and ensure timeliness of information\nLinking together disparate data sources to drive insight\nSupport trading investigations by building alerting on key metrics\nWork closely with the Customer Insights team to track performance of ROI of promotions\nWork closely with the vertical specific analysts to support on detailed analysis of promotions\nPerform exploratory analysis that interrogates, supports and challenges business assumptions\nRequirements of special knowledge/skills\nExperience of multivariate testing \nAble to weave a narrative when presenting data\nStrong experience of leveraging insights from disparate data ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Job Title        108 non-null    object
#  1   Job Description  108 non-null    object
# dtypes: object(2)
# memory usage: 1.8+ KB

# %%
x = df['Job Description'].sample(5).str.split('\n', expand=True)

# %%
x
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              0  \
# 64  At Booking.com, our mission is to make it easier for everyone to experience the world. And while that world might feel a little farther away right now, we’re busy preparing for when the world is ready to travel once more. With strategic long-term investments into what we believe the future of travel can be, we are opening career opportunities that will have a strong impact on our mission.
# 89  At Booking.com, data drives our decisions. Technology is at our core and innovation is everywhere. But our company is more than datasets, lines of code or A/B tests. We’re the thrill of the first night in a new place and the excitement of the next morning. The friends you make, the journeys you take, the sights you see and the food you sample. Through our products, partners and people, we can empower everyone to experience the world.
# 84  As a Key Account Manager, you are responsible for managing the relationship we have with our existing Accommodation Partners. In addition, you may support Booking.com BV’s acquisition of new Partners through negotiations. You create in-depth quantity and quality reports on results and performance and advise all relevant departments on how to optimize their performance on Booking.com. You proactively inform Key Partners about the benefits of Booking.com products and services. You will be responsible for the improvement of Key Accommodations Partner’s availability and supply in order to support Booking.com in meeting the demands of the visitors on the Booking.com website. As part of this team, you will need to work closely with other departments such as Connectivity, Hotel Innovations, Credit Control and the Hotels teams based in Booking.com’s local offices within the wider region. To be successful in this role you will need to demonstrate strong networking skills in order to connect with different stakeholders within Booking.com as well as within the Hotel Industry and within Hotel.
# 70  Our Company
# 56  It wasn’t so long ago that booking a trip to see the Eiffel Tower, stroll down New York’s iconic Madison Avenue or feel the sand between our toes on Copacabana Beach was simply a matter of a few taps on our smartphone. In fact, that’s what we do at Booking.com. We make it easier for everyone to experience the world. And while that world might feel a little farther away right now, we’re busy preparing for when the world is ready to travel once more.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                      1  \
# 64  Core Infrastructure
# 89  Our IT Services Department is providing Booking.com workforce with all the systems and functionality they need to do their best work. From the laptop, Wi-Fi connection, communication channels to seamless access on all the applications being used. IT Services is responsible for delivery, service and support of this complete environment, running on  a global infrastructure spread over 100+ offices for 15K+ employees.
# 84  This full-time position is be based in our Taipei office.
# 70  Founded in 1996 in Amsterdam, Booking.com has grown from a small Dutch start-up to one of the world’s leading digital travel companies. Part of Booking Holdings Inc. (NASDAQ: BKNG), Booking.com’s mission is to make it easier for everyone to experience the world.
# 56  Staying the leader in accommodations is a top priority for Booking. The market represents a large share of business already, and yet is one of the markets with the most untapped opportunities.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   2  \
# 64  Do you want to build software that impacts millions of customers around the world, tackling some of the world's most complex ecommerce challenges? We are looking for talented infrastructure backend developers to join our Core Infrastructure department in our Amsterdam HQ.
# 89  IT Services Operations
# 84  B.responsible
# 70  By investing in technology that takes the friction out of travel, Booking.com seamlessly connects millions of travelers to memorable experiences, a variety of transportation options, and incredible places to stay – from homes to hotels, and much more. As one of the world’s largest travel marketplaces for both established brands and entrepreneurs of all sizes, Booking.com enables properties around the world to reach a global audience and grow their businesses.
# 56    One of these opportunities is to make our user experience personalised, relevant, and scalable. This involves exploring new UX paradigms, ensuring that we show the right products for our users at every stage of their journey, and personalising using Machine Learning and allied data products. As a Machine Learning Engineer within the Web Core ML team, you will be responsible for creating the ML platform that powers up personalization capabilities.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  3  \
# 64  In Core Infrastructure we design, build and operate all the technology that our Booking.com product development teams need in order to deliver great travel products to our customers.
# 89  The IT Services Operations team finds its core in monitoring & alerting, issue handling and change support for  the Voice Communications and Network environments within the IT Services Department. The ITS Operations team is positioned within the Corporate Network track. Together with the other tracks around systems/applications/support they will add focus to the ITSM processes Incident-, Problem- and Change management. With new responsibilities like Major Incident Management, proactive communication and change coordination they will bring the ITS service-experience to the next level.
# 84  Support Booking.com BV’s-strategy for Key Partners;
# 70  At Booking.com, we are all involved in making hundreds of decisions every day. The decisions we make are a reflection of our values -  they reflect what is important to us, both as individuals and as an organization.
# 56    B.Responsible
#
#                                                                                                                                                                                                                                                                                                                                                                                                                     4  \
# 64  This includes, for instance, our on premise data centers, our cloud hosted Kubernetes clusters, MySQL/Cassandra/Elasticsearch database environment, HAProxy load balancers, Envoy service mesh, APigee gateway, Kafka streaming service, Hadoop big data storage, Graphite time series, Grafana dashboard platform, monitoring & alerting tools, CI/CD tooling, Perl/Java/Node.js language frameworks and more...
# 89  Manager Operations IT Services
# 84  Promote the Booking.com BV brand name and its online products and services to Key Partners;
# 70  Booking.com was recently ranked #3 in the Financial Times’ 2021 Diversity Leaders list of European employers, and we couldn’t be more proud. It’s a great recognition for our colleagues around the world, who effortlessly work to create a welcoming and open environment in which people can connect and learn from each other.
# 56  Translate specific business problems into ML/AI challenges and identify the best approach within the constraints of the production environment. Build proof-of-concepts to test new ideas and demonstrate their potential value to relevant stakeholders.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                  5  \
# 64  Responsible
# 89  As the Manager Operations you will lead the ITS Operations team with 5 to 10 employees. The team is at the start of its journey and both the team itself and its services will face a lot of exciting challenges and growth. Next to the Operations Management itself, the definition, coordination and implementation of the ITSM processes and its environments like ServiceNow, monitoring and reporting, will be a major part of your job.
# 84  Create in-depth Key Account profiles that show understanding of the complexity of the Account;
# 70  Marketing Messaging
# 56  Develop production-grade machine learning code, from models to features and pipelines, allowing for scalability, realtime inference, monitoring and retraining. Monitor product health, performance and business impact and act accordingly when not met.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                            6  \
# 64  Combine hands on coding with working on impactful project(s) and supporting other team members,
# 89  Are you as passionate about Operations as we are, proactive, an excellent communicator and motivator? Does ITSM have no secrets for you? Then we have a great opportunity for you!
# 84  Be the relationship builder for various internal and external stakeholders that are involved in the specific Key Account;
# 70  Marketing Messaging is a multi-channel, ever-changing, complex and high business impact area. To achieve Booking.com’s mission, we need to bring real value to our customers with every message we send them. Messaging infrastructure and platform capabilities are foundational in achieving this mission. We have a multifunctional team of software engineers, data scientists, product managers, designers and marketers to make all this possible.
# 56  Build readable and reusable code, choosing the right technologies, coding methodologies, and approach from carefully designed rapid prototyping to software deployment at scale. Identify opportunities for platform-based development and reuse by abstracting business problems to generalized ML/AI solutions.
#
#                                                                                                                                                                                                                                                                                                          7  \
# 64  Solve business problems, work cross-functionally and lead initiatives to improve our development process and business opportunities within Booking.com,
# 89  B.responsible
# 84  Train, consult, monitor, support internal and external stakeholders in handling the Key Accounts in order to optimize their performance;
# 70  Senior Tech Product Manager - Marketing Messaging
# 56  Execute applied research plans for machine intelligence on a specific product by designing innovative ML/AI models, algorithms, and approaches that deliver both short-term commercial impact and longer-term differentiated business value and customer experiences. Document and share the findings.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         8  \
# 64  Take initiative to address the larger technical needs of the product you work on and always keep the customer at the center of everything you do,
# 89  The Booking.com workforce, your customer, is always proactively informed about the quality and status of the products and services they use (Service Catalog - Customer Products).
# 84  Securing our relationship and optimizing our partnership on a decision making level with Key Accounts of Booking.com B.V;
# 70  We are searching for an experienced Senior Technology Product Manager to define the future of Marketing Messaging infrastructure and platform, integrate new communication channels, develop tools and APIs. You will work across multiple teams and departments, collect and analyse customers feedback and internal stakeholder requirements, translate business needs into technical requirements and product roadmaps. Alongside a group of product managers you will develop and support a long term engagement strategy aiming to maximise Customer Equity, increase our customer base, increase teams efficiency and their impact using platform capabilities.
# 56  Maintain a highly cross-disciplinary perspective, solving issues by applying approaches and methods from across a variety of ML/AI disciplines and related fields. Coach others through evidence and clear communication, explaining advanced technical concepts.
#
#                                                                                                                                                                         9  \
# 64  Contribute to the growth of Booking.com through recruitment efforts and proactively share your knowledge to help your colleagues grow,
# 89  The ITSM processes and its activities are monitored and reported on towards management and customers (Service Levels)
# 84  Initiate initiatives and present Booking.com B.V. innovations with Key Accounts to increase performance;
# 70  This is a fantastic opportunity to make a difference in marketing messaging at Booking.com. A background in email marketing, multi-channels messaging is required.
# 56  Identify underlying issues and opportunities across domains and situations through application of structured thinking and logic, and formulate possible improvements.
#
#     ...  \
# 64  ...
# 89  ...
# 84  ...
# 70  ...
# 56  ...
#
#                                                                                                 42  \
# 64  Opportunity to utilize technical expertise, leadership capabilities and entrepreneurial spirit
# 89  None
# 84  None
# 70  We offer
# 56  None
#
#                                                                                                                                                                                                                                                                                   43  \
# 64  Promote and drive impactful and innovative engineering solutions
# 89  None
# 84  None
# 70  This role is open to worldwide candidates. We provide assistance for you and your family with a generous relocation package, ensuring a smooth transition to working and living in Amsterdam. We have successfully relocated thousands of technology professionals to Amsterdam.
# 56  None
#
#                                                                                                                                                                                  44  \
# 64  Technical, behavioural and interpersonal competence advancement via on-the-job opportunities, experimental projects, hackathons, conferences and active community participation
# 89  None
# 84  None
# 70  Headquarters located in one of the most vibrant cities in Europe: Amsterdam
# 56  None
#
#                                                                                                                                                45  \
# 64  Competitive compensation and benefits package and some great added perks of working in the home city of Booking.com
# 89  None
# 84  None
# 70  Performance-based company that offers 29 vacation days, career advancement, and lucrative compensation, including bonuses and stock potential
# 56  None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                        46  \
# 64  Booking.com is proud to be an equal opportunity workplace and is an affirmative action employer. All qualified applicants will receive consideration for employment without regard to race, colour, religion, gender, gender identity or expression, sexual orientation, national origin, genetics, disability, age, or veteran status. We strive to move well beyond traditional equal opportunity and work to create an environment that allows everyone to thrive.
# 89  None
# 84  None
# 70  Discount on Booking.com accommodations with the “Booking Deal” including other perks and benefits
# 56  None
#
#                                                                                                                           47  \
# 64  None
# 89  None
# 84  None
# 70  Company-sponsored family and social activities to help our employees become integrated with each other and Dutch culture
# 56  None
#
#                                                                                                                           48  \
# 64  None
# 89  None
# 84  None
# 70  Competence advancements via online resources, trainings, on-the-job opportunities, conferences and community initiatives
# 56  None
#
#                                                49  \
# 64  None
# 89  None
# 84  None
# 70  Competitive compensation and benefits package
# 56  None
#
#                                                            50  \
# 64  None
# 89  None
# 84  None
# 70  Diverse, unique colleagues from every corner of the world
# 56  None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                        51
# 64  None
# 89  None
# 84  None
# 70  Booking.com is proud to be an equal opportunity workplace and is an affirmative action employer. All qualified applicants will receive consideration for employment without regard to race, colour, religion, gender, gender identity or expression, sexual orientation, national origin, genetics, disability, age, or veteran status. We strive to move well beyond traditional equal opportunity and work to create an environment that allows everyone to thrive.
# 56  None
#
# [5 rows x 52 columns]

# %%
# Out:
# <style>.container { width:100% !important; }</style>
